# %%
import os
os.chdir('~/GAME_0527/src/')

# %%
# %run main.py --path '~/GAME_0527/' --batch_size 1024 --epochs 500 --drop_out 0.5 --scale_sppmi 1e-4 --lr 1e-8 --min_lr 5e-7 --hidden_features 768 --DEVICE 'cuda' --path_origin '2024-08-28 20:07:37' --align_path '2024-08-23 14:19:22'

# %%
# use sim_51

# %%
# %run main.py --path '/n/data1/hsph/biostat/celehs/lab/hat127//GAME_ablation_all/GAME_no_contrastive/' --epochs 500 --drop_out 0.5 --scale_sppmi 0.1 --lr 1e-6 --hidden_features 768 --DEVICE 'cuda' --path_origin '2024-08-28 20:07:37' --align_path '2024-08-23 14:19:22' --api_key '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'
# Out:
# load aligned sppmi embedding!
# 2025-05-11 10:43:50,935 - INFO - inst_encoder(
#   (GAT_together): GATLayer(
#     (gat_conv): GATConv(1536, 768, heads=2)
#     (batch_norm): BatchNorm1d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU()
#   )
#   (Linear): Linear(in_features=1536, out_features=512, bias=True)
# )
# load similarity embedding!
# All logs will be saved to /n/data1/hsph/biostat/celehs/lab/hat127//GAME_ablation_all/GAME_no_contrastive//output/2025-05-11 10:43:48/2025-05-11 10:43:48.log
# undirected_edge_index.shape = torch.Size([2, 608578])
# 2025-05-11 11:04:39,375 - INFO - EPOCH: 001     Saved model...   All time ELAPSED: 1250.95s
# 2025-05-11 11:04:39,379 - INFO - EPOCH: 001     LOSS: 8428.7510     ELAPSED: 1246.58s

# %%
# %run main.py --path '/n/data1/hsph/biostat/celehs/lab/hat127//GAME_ablation_all/GAME_no_contrastive/' --epochs 500 --drop_out 0.5 --EDGE_ALL --scale_sppmi 0.1 --lr 1e-6 --hidden_features 768 --DEVICE 'cuda' --path_origin '2024-08-28 20:06:59' --align_path '2024-08-23 14:19:22' --api_key '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'
# Out:
# load aligned sppmi embedding!
# 2024-08-29 19:13:58,999 - INFO - inst_encoder(
#   (GAT_together): GATLayer(
#     (gat_conv): GATConv(1536, 768, heads=2)
#     (batch_norm): BatchNorm1d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (activation): ReLU()
#   )
#   (Linear): Linear(in_features=1536, out_features=512, bias=True)
# )
# load similarity embedding!
# All logs will be saved to /home/doz128/GAME_0726//output/2024-08-29 19:13:54/2024-08-29 19:13:54.log
# undirected_edge_index.shape = torch.Size([2, 608578])
# 50738
# 50738
# sppmi_pos_loss: 0.11550121754407883
# sppmi_neg_loss: 0.37259942293167114
# SapBERT: 0.038	CODER: 0.18	BGE: 0.228	OPENAI: 0.513	MGB SPPMI: 0.317	VA SPPMI: 0.274	UPMC SPPMI: 0.196	BCH SPPMI: 0.204	Duke SPPMI: -0.011	MIMIC SPPMI: -0.246	Bor SPPMI: 0.276	GAME: 0.457
# ...
